# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
g_1 = np.array([0.0127309,  0.0253852,      0.0379638,      0.0504673,      0.0628965,
                0.0752522,      0.0875351,      0.0997458,       0.111885,       0.123954,
                0.135952,       0.147882,       0.159743,       0.171535,       0.183261,
                0.19492,       0.206513,       0.218041,       0.229504,       0.240903,
                0.252239,       0.263512,       0.274723,       0.285873,       0.296961,
                0.307989,       0.318958,       0.329868,       0.340719,       0.351512,
                0.362247,       0.372926,       0.383549,       0.394116,       0.404628,
                0.415085,       0.425489,       0.435838,       0.446135,        0.45638,
                0.466572,       0.476713,       0.486803,       0.496843,       0.506833,
                0.516773,       0.526665,       0.536508,       0.546303,       0.556051,
                0.565752,       0.575406,       0.585014,       0.594576,       0.604094,
                0.613566,       0.622994,       0.632379,        0.64172,       0.651018,
                0.660273,       0.669487,       0.678658,       0.687788,       0.696878,
                0.705927,       0.714936,       0.723905,       0.732835,       0.741726,
                0.750578,       0.759392,       0.768169,       0.776908,        0.78561,
                0.794275,       0.802905,       0.811498,       0.820055,       0.828578,
                0.837065,       0.845518,       0.853937,       0.862322,       0.870674,
                0.878992,       0.887277,        0.89553,       0.903751,        0.91194,
                0.920097,       0.928223,       0.936318,       0.944382,       0.952416,
                0.96042,       0.968395,       0.976339,       0.984255,       0.992142])
gs_1 = np.array([0.0126923,     0.0253086,     0.0378495,     0.050316,     0.0627087,
                 0.0750284,     0.0872759,     0.099452,     0.111557,     0.123593,
                 0.135559,     0.147456,     0.159286,     0.171048,     0.182745,
                 0.194375,     0.20594,     0.217441,     0.228878,     0.240252,
                 0.251564,     0.262814,     0.274002,     0.28513,     0.296198,
                 0.307207,     0.318157,     0.32905,     0.339884,     0.350662,
                 0.361383,     0.372049,     0.382659,     0.393214,     0.403716,
                 0.414164,     0.424559,     0.434901,     0.445192,     0.455431,
                 0.465619,     0.475757,     0.485845,     0.495883,     0.505873,
                 0.515814,     0.525707,     0.535552,     0.545351,     0.555103,
                 0.564809,     0.574469,     0.584084,     0.593654,     0.60318,
                 0.612662,     0.6221,     0.631496,     0.640848,     0.650159,
                 0.659428,     0.668655,     0.677841,     0.686987,     0.696092,
                 0.705157,     0.714183,     0.72317,     0.732118,     0.741027,
                 0.749899,     0.758733,     0.767529,     0.776289,     0.785012,
                 0.793698,     0.802349,     0.810964,     0.819544,     0.828089,
                 0.836599,     0.845075,     0.853517,     0.861925,     0.8703,
                 0.878642,     0.886951,     0.895227,     0.903472,     0.911684,
                 0.919865,     0.928015,     0.936133,     0.944221,     0.952279,
                 0.960306,     0.968304,     0.976271,     0.98421,     0.992119])

# %%
epsilon = 1
a = 1/2

x = np.arange(0.0, 1, 0.01)
y = (1-a) / (1 - np.e**(-1/epsilon)) * (1 - np.e**(-x/epsilon)) + a * x


plt.figure(dpi=240)
plt.plot(x, y, label=f'accuracy')
plt.plot(x, g_1, label='Gauss')
plt.plot(x, gs_1, label='Gauss-Seidel')
plt.title(f'ε = {epsilon}')
plt.legend()
plt.show()
